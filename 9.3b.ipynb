# %%
h = 0.001
r = 0
l = -10
y = 1
while abs(y) > 1e-5:
    h = 0.001
    z = 0.5 * (l + r)
    y = 1
    for i in range(1, 1001):
        z = z - h * 0.5 * (z ** 2) / (1-0.5*y)
        y = y + z * h
    if (abs(y) > 1e-5) & (y > 0):
        r = 0.5 * (l + r)
    elif (abs(y) > 1e-5) & (y < 0):
        l = 0.5 * (l + r)
print(0.5 * (l + r))

y = 1
z = 0.5 * (l + r)
for i in range(1, 1001):
        z = z - h * 0.5 * (z ** 2) / (1-0.5*y)
        y = y + z * h
        print(h * i, y)
# Out:
# 3.3443056979406624e-07 -0.6930732727050781
# 0.001 0.9993064463767336
# 0.002 0.9986124120702184
# 0.003 0.997917896747537
# 0.004 0.9972229000755409
# 0.005 0.9965274217208518
# 0.006 0.9958314613498602
# 0.007 0.9951350186287258
# 0.008 0.9944380932233773
# 0.009000000000000001 0.9937406847995122
# 0.01 0.9930427930225965
# 0.011 0.9923444175578646
# 0.012 0.9916455580703196
# 0.013000000000000001 0.9909462142247324
# 0.014 0.990246385685642
# 0.015 0.9895460721173552
# 0.016 0.9888452731839464
# 0.017 0.9881439885492577
# 0.018000000000000002 0.9874422178768982
# 0.019 0.9867399608302446
# 0.02 0.9860372170724404
# 0.021 0.9853339862663959
# 0.022 0.9846302680747883
# 0.023 0.983926062160061
# 0.024 0.9832213681844241
# 0.025 0.9825161858098538
# 0.026000000000000002 0.9818105146980923
# 0.027 0.9811043545106478
# 0.028 0.9803977049087942
# 0.029 0.9796905655535708
# 0.03 0.9789829361057826
# 0.031 0.9782748162259994
# 0.032 0.9775662055745566
# 0.033 0.9768571038115543
# ...
