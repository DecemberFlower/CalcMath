# %%
h = 0.001
l = 0
r = 10
while abs(s - 1) > (1e-4):
    s = 0
    y0 = 0
    y = 0
    z = 0.5 * (l + r)
    for i in range(1, 1001):
        z = z + h * (h * i * y ** 0.5)
        y0 = y
        y = y + h * z
        s += h/2 * (y + y0)
    if (s > 1) & (abs(s - 1) > 1e-4):
        r = 0.5 * (l + r)
    if (s < 1) & (abs(s - 1) > 1e-4):
        l = 0.5 * (l + r)
s = 0
y0 = 0
y = 0
z = (l + r) / 2
for i in range(1, 1001):
    z = z + h * (h * i * y ** 0.5)
    y0 = y
    y = y + h * z
    s += h/2 * (y + y0)
    print(h * i, y)
# Out:
# 0.001 0.005
# 0.002 0.010000000141421356
# 0.003 0.015000000582842715
# 0.004 0.02000000151416203
# 0.005 0.025000003152588154
# 0.006 0.030000005739697636
# 0.007 0.0350000095392428
# 0.008 0.040000014835451125
# 0.009000000000000001 0.04500002193165978
# 0.01 0.05000003114918929
# 0.011 0.05500004282639435
# 0.012 0.06000005731784996
# 0.013000000000000001 0.06500007499364376
# 0.014 0.07000009623875326
# 0.015 0.07500012145249248
# 0.016 0.0800001510480157
# 0.017 0.08500018545186956
# 0.018000000000000002 0.09000022510358587
# 0.019 0.09500027045530929
# 0.02 0.10000032197145549
# 0.021 0.10500038012839547
# 0.022 0.11000044541416312
# 0.023 0.11500051832818324
# 0.024 0.12000059938101768
# 0.025 0.1250006890941278
# 0.026000000000000002 0.1300007879996514
# 0.027 0.13500089664019294
# 0.028 0.14000101556862557
# 0.029 0.14500114534790398
# 0.03 0.15000128655088715
# 0.031 0.1550014397601702
# 0.032 0.16000160556792434
# 0.033 0.16500178457574471
# 0.034 0.17000197739450507
# ...
